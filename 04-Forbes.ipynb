# %% [markdown]
# # Forbes Billionaires
#
# [Forbes Billionaire list](https://www.forbes.com/billionaires/)

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import sys
sys.path.append("./forbes/")
from forbes import parse_top

# %%
parse_top()

# %%
df = pd.read_csv("./forbes/lines.csv", delimiter='|', names=['Rank','Name','Net Worth','Change','Age','Country/Territory','Source','Industry','control'])

# %%
df.iloc[915:950, :]
# Out:
#      Rank                       Name Net Worth         Change   Age  \
# 915   905                 David Filo    $3.2 B     down arrow  56.0
# 916   905                Lindsay Fox    $3.2 B       up arrow  85.0
# 917   905            Sergei Galitsky    $3.2 B      unchanged  55.0
# 918   905   Senapathy Gopalakrishnan    $3.2 B     down arrow  67.0
# 919   905               Luciano Hang    $3.2 B     down arrow  60.0
# 920   905             Michael Hintze    $3.2 B      unchanged  69.0
# 921   905                  Hu Baifan    $3.2 B     down arrow  60.0
# 922   905    Hamilton James & family    $3.2 B       up arrow  71.0
# 923   905                Lee Boo-jin    $3.2 B     down arrow  52.0
# 924   905                Li Liangbin    $3.2 B     down arrow  55.0
# 925   905                 Liang Feng    $3.2 B     down arrow  54.0
# 926   905                Samir Mehta    $3.2 B       up arrow  59.0
# 927   905               Sudhir Mehta    $3.2 B       up arrow  68.0
# 928   905     Aristotelis Mistakidis    $3.2 B     down arrow  61.0
# 929   905            Geoffrey Palmer    $3.2 B    new to list  72.0
# 930   905               Roger Penske    $3.2 B       up arrow  86.0
# 931   905                Ravi Pillai    $3.2 B       up arrow  69.0
# 932   905           David Rubenstein    $3.2 B     down arrow  73.0
# 933   905          Hilton Schlosberg    $3.2 B       up arrow  70.0
# 934   905    Klaus-Peter Schulenberg    $3.2 B       up arrow  71.0
# 935   905  Lynn Schusterman & family    $3.2 B     down arrow  84.0
# 936   905         Isabella Seràgnoli    $3.2 B       up arrow  77.0
# 937   905                Shen Guojun    $3.2 B     down arrow  60.0
# 938   905            Warren Stephens    $3.2 B       up arrow  66.0
# 939   905                Pat Stryker    $3.2 B       up arrow  66.0
# 940   905            Roman Trotsenko    $3.2 B  list returnee  52.0
# 941   905             Harald Tschira    $3.2 B            NaN  48.0
# 942   905                Udo Tschira    $3.2 B            NaN  53.0
# 943   905              Vincent Viola    $3.2 B     down arrow  67.0
# 944   905                 Wu Shaoxun    $3.2 B     down arrow  67.0
# 945   905                 Steve Wynn    $3.2 B     down arrow  81.0
# 946   905              Jon Yarbrough    $3.2 B       up arrow  65.0
# 947   905                 Zhou Bajin    $3.2 B     down arrow  87.0
# 948   949               Cho Tak Wong    $3.1 B     down arrow  76.0
# 949   949                John Coates    $3.1 B       up arrow  53.0
#
#     Country/Territory                               Source  \
# 915     United States                                Yahoo
# 916         Australia               Logistics, real estate
# 917            Russia                               Retail
# 918             India                    Software services
# 919            Brazil                    Department stores
# 920         Australia                           Investment
# 921             China                      Pharmaceuticals
# 922     United States                          Investments
# 923       South Korea                              Samsung
# 924             China                              Lithium
# 925             China                        Manufacturing
# 926             India               Pharmaceuticals, power
# 927             India               Pharmaceuticals, power
# 928            Greece                  Mining, commodities
# 929     United States                          Real estate
# 930     United States                                 Cars
# 931             India                         Construction
# 932     United States                       Private equity
# 933    United Kingdom                        Energy drinks
# 934           Germany                    Ticketing service
# 935     United States               Oil & gas, investments
# 936             Italy                            Packaging
# 937             China                               Retail
# 938     United States                   Investment banking
# 939     United States                    Medical equipment
# 940            Russia  Transport, engineering, real estate
# 941           Germany                             Software
# 942           Germany                             Software
# 943     United States                   Electronic trading
# 944             China                                 Wine
# 945     United States                      Casinos, hotels
# 946     United States                          Video games
# 947             China                           Auto parts
# 948         Hong Kong                           Auto parts
# 949    United Kingdom                      Online gambling
#
#                        Industry  control
# 915                  Technology      NaN
# 916                   Logistics      NaN
# 917            Fashion & Retail      NaN
# 918                  Technology      NaN
# 919            Fashion & Retail      NaN
# 920       Finance & Investments      NaN
# 921                  Healthcare      NaN
# 922       Finance & Investments      NaN
# 923                  Technology      NaN
# 924               Manufacturing      NaN
# 925               Manufacturing      NaN
# 926                  Healthcare      NaN
# 927                  Healthcare      NaN
# 928             Metals & Mining      NaN
# 929                 Real Estate      NaN
# 930                  Automotive      NaN
# 931  Construction & Engineering      NaN
# 932       Finance & Investments      NaN
# 933             Food & Beverage      NaN
# 934                     Service      NaN
# 935                      Energy      NaN
# 936               Manufacturing      NaN
# 937            Fashion & Retail      NaN
# 938       Finance & Investments      NaN
# 939                  Healthcare      NaN
# 940                   Logistics      NaN
# 941                  Technology      NaN
# 942                  Technology      NaN
# 943       Finance & Investments      NaN
# 944             Food & Beverage      NaN
# 945          Gambling & Casinos      NaN
# 946          Gambling & Casinos      NaN
# 947               Manufacturing      NaN
# 948               Manufacturing      NaN
# 949          Gambling & Casinos      NaN

# %%
df['Net Worth Num'] = pd.to_numeric(df['Net Worth'].str.split(' ')[:].str[0].str[1:])

# %%
df.tail()
# Out:
#      Rank                   Name Net Worth       Change   Age  \
# 995   982  Edward DeBartolo, Jr.      $3 B     up arrow  76.0
# 996   982        Stephen Deckoff      $3 B  new to list  57.0
# 997   982          Feng Hailiang      $3 B     up arrow  62.0
# 998   982     Ernest Garcia, II.      $3 B   down arrow  65.0
# 999   982                Sam Goi      $3 B     up arrow  76.0
#
#     Country/Territory             Source               Industry  control  \
# 995     United States   Shopping centers            Real Estate      NaN
# 996     United States     Private equity  Finance & Investments      NaN
# 997             China  Copper, education        Metals & Mining      NaN
# 998     United States          Used cars             Automotive      NaN
# 999         Singapore       Frozen foods        Food & Beverage      NaN
#
#      Net Worth Num
# 995            3.0
# 996            3.0
# 997            3.0
# 998            3.0
# 999            3.0

# %%
df.drop(columns='control').to_csv("./forbes/forbes.csv", index=False)

# %%
df.drop(columns='control')
# Out:
#      Rank                      Name Net Worth      Change   Age  \
# 0       1  Bernard Arnault & family    $211 B    up arrow  74.0
# 1       2                 Elon Musk    $180 B  down arrow  51.0
# 2       3                Jeff Bezos    $114 B  down arrow  59.0
# 3       4             Larry Ellison    $107 B    up arrow  78.0
# 4       5            Warren Buffett    $106 B  down arrow  92.0
# ..    ...                       ...       ...         ...   ...
# 595   591              Vladimir Kim    $4.6 B  down arrow  62.0
# 596   591            Andre Koo, Sr.    $4.6 B  down arrow  55.0
# 597   591             Ronald Lauder    $4.6 B  down arrow  79.0
# 598   591                 Li Chunan    $4.6 B  down arrow  54.0
# 599   591                Forrest Li    $4.6 B  down arrow  45.0
#
#     Country/Territory                    Source               Industry  \
# 0              France                      LVMH       Fashion & Retail
# 1       United States             Tesla, SpaceX             Automotive
# 2       United States                    Amazon             Technology
# 3       United States                    Oracle             Technology
# 4       United States        Berkshire Hathaway  Finance & Investments
# ..                ...                       ...                    ...
# 595        Kazakhstan                    Mining        Metals & Mining
# 596            Taiwan        Financial services  Finance & Investments
# 597     United States              Estee Lauder       Fashion & Retail
# 598             China  Solar wafers and modules          Manufacturing
# 599         Singapore                    Gaming  Media & Entertainment
#
#      Net Worth Num
# 0            211.0
# 1            180.0
# 2            114.0
# 3            107.0
# 4            106.0
# ..             ...
# 595            4.6
# 596            4.6
# 597            4.6
# 598            4.6
# 599            4.6
#
# [600 rows x 9 columns]

# %% [markdown]
# ---
# ## Plots

# %%
fig, ax = plt.subplots(figsize=(6,8))
sns.countplot(data=df, y='Country/Territory', order=list(df['Country/Territory'].value_counts().index), orient='v', ax=ax)

plt.show()

# %%
df[['Country/Territory', 'Net Worth Num']].groupby('Country/Territory').sum().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Country/Territory'>
